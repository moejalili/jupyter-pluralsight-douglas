# %%
import ipywidgets as widgets
from ipywidgets import Output
from IPython.display import display

out = Output()           # I created this here because I will use it in several cells

# %%
import pandas as pd
weather = pd.read_csv('data/TN/weather3.csv')
weather
# Out:
#        Date   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   1/12/08     Albury     13.4     22.9       0.6          NaN       NaN
# 1   2/12/08     Albury      7.4     25.1       0.0          NaN       NaN
# 2   3/12/08     Albury     12.9     25.7       0.0          NaN       NaN
# 3   4/12/08     Albury      9.2     28.0       0.0          NaN       NaN
# 4    5/9/09      Moree     12.9     22.0      12.8          6.6       6.5
# 5    6/9/09      Moree      4.6     23.2       0.0          3.8      11.2
# 6    7/9/09      Moree      9.1     19.6       0.0          4.8       0.0
# 7    8/9/09      Moree      5.5     21.3       4.0          1.6       8.7
# 8    9/9/09      Moree      3.6     20.2       0.0          3.4      11.1
# 9   10/9/09      Moree      4.1     21.7       0.0          4.6      11.3
# 10  15/4/13    Penrith     12.6     26.8       0.2          NaN       NaN
# 11  16/4/13    Penrith     16.0     20.7      18.4          NaN       NaN
# ...

# %%
weather[weather.Location == 'Brisbane']
# Out:
#       Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 25  1/7/08  Brisbane     10.3     25.2       0.0          1.4       9.5
# 26  2/7/08  Brisbane      8.1     22.9       0.0          2.0       9.8
# 27  3/7/08  Brisbane      9.7     22.4       0.0          5.8       9.4
# 28  4/7/08  Brisbane     11.8     20.0       0.8          1.8       1.1
#
#    WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  Pressure9am  \
# 25         WNW             26        SSW  ...          37       1019.6
# 26           W             30          W  ...          30       1018.8
# 27           E             22         SW  ...          52       1021.4
# 28          SW             24         SW  ...          53       1023.5
#
#     Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RISK_MM  \
# 25       1014.8       0.0       1.0     14.9     24.6         No      0.0
# 26       1015.0       0.0       0.0     16.2     22.4         No      0.0
# ...

# %%
weather_cities = ['All'] + list(weather.Location.unique())
#weather_cities
min_temp = ['All'] + list(weather.MinTemp.unique())
#min_temp

# %%
dd_city = widgets.Dropdown(options = weather_cities)
#display(dd_city)
dd_min_temp = widgets.Dropdown(options = min_temp)
#display(dd_min_temp)

# %% [markdown]
# The query only filters by the drop-down, which was recently changed. I want it to work on both values together. So what I really need is a new function to do the querying and have the observe handlers call it, passing the values for the query parameters. The dd_city observer method will call this new method, query_weather, passing the new value from the bunch, but also the current value of the dd_min_temp drop-down, and the dd_min_temp observer method will call query_weather as well, except with the value of the dd_city drop-down and then its new value.

# %%
def query_weather(city, min_temp):
    city_filter = weather if city =='ALL' else weather[weather.Location == city]
    min_temp_filter = city_filter if min_temp == 'All' else city_filter[city_filter.MinTemp == min_temp] 
    with out:
        display(min_temp_filter)

# %%
#def dd_city_observer(bunch):          #I'll create a function for the observer handler that will filter the data frame by the value selected in the drop-down.
#    out.clear_output()                #  To clear this output widget each time the drop-down changes, I'll add a call to the clear_output method of the output widget in the observe handler
#    with out:                         # I'm going to tell the output widget to capture the output of the data frame by calling display inside of a with block.
#        display(weather[weather.Location == bunch.new])
        
#def dd_min_temp_observer(bunch):
#    out.clear_output()                
#    with out:                       
#        display(weather[weather.MinTemp == bunch.new])

# %%
def dd_city_observer(bunch):
    out.clear_output()
    query_weather(bunch.new, dd_min_temp.value)
    
def dd_min_temp_observer(bunch):
    out.clear_output()
    query_weather(dd_city.value, bunch.new)

# %% [markdown]
#  I'll register the observer with the city drop-down and make sure that observe sends a bunch regarding the values.

# %%
dd_city.observe(dd_city_observer, names = 'value')       
dd_min_temp.observe(dd_min_temp_observer, names = 'value')

# %%
display(dd_city)
display(dd_min_temp)
# Out:
# Dropdown(options=('All', 'Albury', 'Moree', 'Penrith', 'Sydney', 'GoldCoast', 'Brisbane'), value='All')
# Dropdown(options=('All', 13.4, 7.4, 12.9, 9.2, 4.6, 9.1, 5.5, 3.6, 4.1, 12.6, 16.0, 12.5, 13.5, 12.1, 13.0, 16…

# %% [markdown]
# For refereshing the table each time and clearing the last one : >>> adding widget __Output__ that need to be imported

# %%
display(out)
# Out:
# Output()

# %% [markdown]
# ### Finally I could bring tempretures filtered by cities!! why? Review this one later
